# %% [markdown]
# # Camera Trap to Random Forests in Python

# %%
import os
os.chdir("C:/Users/athellma/OneDrive - University of North Carolina at Chapel Hill/Documents/Duke University/Research/_HBEF/CameraTrapAnalysis/hbwater_cameratrap_pheno")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
from datetime import datetime as dt
import ast
import itertools
from PIL import Image
#import packages
import pytesseract
#Set tesseract location
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe" 
import glob
import cv2
import re

# %% [markdown]
# ### Wrangle the Data

# %%
def extract_temperature(pic_address):
    '''
    Extract temperature from picture file.

    From the middle of each picture file, the time stamp is read as image using cv2. It is then converted to a string.
    text which is then checked for format and subsequently returned through temp_format.

    Parameters
    ----------
    pic_address : full source address of current picture file.
    Returns
    -------
    temp_format.group(0) : unaltered temperature from bottom of the photo as a string.
    '''

    img = cv2.imread(pic_address) #read as an image

    # check if the timestamp is the correct format
    temp_pattern = "\d\dF" # eg 37F3C or 30F-1C

    loop = 5
    size_extension=0
    x,y,z = np.shape(img)
    x = (x//1000)*1000

    y = (y//1000)*1000
    # print(x,y,z)
    while loop>0:
        ts = img[2300 - size_extension:, 1400-size_extension:, :] #(change start values manually if sizing conventions change!)
        text = pytesseract.image_to_string(ts)
        temp_format = re.search(temp_pattern,text)
        if temp_format:
            # found temperature, return
            break
        ts_2 = img[2430 - size_extension:, 1565-size_extension:, :] #(change start values manually if sizing conventions change!)
        text_2= pytesseract.image_to_string(ts_2)
        temp_format = re.search(temp_pattern,text_2)
        if temp_format:
        # found temperature, return
            break
        size_extension+=50
        loop-=1

    if loop ==0:      
      # reached end of loop without finding correct timestamp
        return np.nan
        # return None
    
    return temp_format.group(0)
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\d'
# <>:19: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\athellma\AppData\Local\Temp\ipykernel_16572\1198062038.py:19: SyntaxWarning: invalid escape sequence '\d'
#   temp_pattern = "\d\dF" # eg 37F3C or 30F-1C

# %%
extract_temperature("example_data/invert_Hbwtr_w3_20201107_115913.JPG") #extract temperature doesn't work on inverted images
# Out:
# C:\Users\athellma\AppData\Local\Temp\ipykernel_16572\1198062038.py:19: SyntaxWarning: invalid escape sequence '\d'
#   temp_pattern = "\d\dF" # eg 37F3C or 30F-1C
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 extract_temperature("example_data/invert_Hbwtr_w3_20201107_115913.JPG") #extract temperature doesn't work on inverted images
#
# Cell In[3], line 23, in extract_temperature(pic_address)
#      21 loop = 5
#      22 size_extension=0
# ---> 23 x,y,z = np.shape(img)
#      24 x = (x//1000)*1000
#      26 y = (y//1000)*1000
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
def wrangle_data_old(df):
    """
    wrangle via annotated data to produce dataframe of pixel coordinates with their corresponding
    RGB values, class and temperature info
    
    """
    # extract region attributes to produce class variable
    for i in range(df.shape[0]):
        try:
            json_item = json.loads(df['region_attributes'][i])
            keys = list(json_item["attribute"].keys())
            df.loc[i,"class"] = keys[0]
        except:
            print("Not able to extract region attributes at row {}".format(i))
    
    # convert json code to python dictionary
    for i in range(df.shape[0]):
        dictionary = ast.literal_eval(df.loc[i, "region_shape_attributes"])
        for k,v in dictionary.items():
            df.loc[i,k ] = v
        
    # change to int type
    for col in ["x", "y", "width","height"]:
        df[col] = df[col].astype('Int64')
        
    # dictionary of filename data
    filename_data = {
        'system': [],
        'watershed': [],
        'date': [],
        'pic_id': [],
    }

    # loop through filename string to add filename data
    for i in range(len(df['filename'])): #used to be file name now invert 
        # split contents by underscore
        file_items = df['filename_inverted'][i].split('_')

        # add system column for 'hbwtr'
        filename_data['system'].append(file_items[1])
        # add watershed olumn, 'w1', 'w2', etc.
        filename_data['watershed'].append(file_items[2])
        # add date column
        filename_data['date'].append(
                                    # modify integer date to date format, MM/DD/YYYY
                                    dt.strptime(file_items[3], '%Y%m%d').strftime('%m/%d/%Y')
                                    )
        # add picture id number
        filename_data['pic_id'].append(file_items[4])

    # create columns of this data in dataframe
    for variable in filename_data.keys():
        df[variable] = filename_data[variable]
        

    # make list to reorder columns
    new_cols = ['filename', 'region_count', 'region_id', 'class', 'name', 'x','y', 'width', 'height',  'system','watershed', 'date', 'pic_id']

    df = df[new_cols]
    
    # create image dictionary and temperature dictionary
    image_dict = {}
    temp_dict = {}
    def my_func(row):
        if row["filename"] in image_dict:
            return
        path =  "example_data/"+row["filename"] # sample path to example data folder with all images
        # note to Audrey: can you change this to read the images recursively (e.g. find file regardless of path)
        img= np.asarray(Image.open(path)) #note to Audrey: read in raw images, not inverted images?
        image_dict[row["filename"]] = img
        temp_dict[row["filename"]] = extract_temperature(path)
    _ = df.apply(lambda c: my_func(c),axis=1)
    
    
    # Assign image pixel values for each row by extracting RGB using x,y coordinates
    
    # drop na values in x and y column
    df = df.dropna(subset= ["x","y"])
    # save new data points to this list
    li = []
    # loop over all rows and poopulate pixel coordinates
    for ind, row in df.iterrows():
        y_range = (row.y, row.y+row.height)
        x_range = (row.x, row.x+row.width)
        # print(y_range, x_range)
        # calculate the coordinates range in the x and y axis
        range_list =  [range(row.x, row.x+row.width), range(row.y,row.y+row.height)]
        # set product of x_range and y_range
        combination_list = list(itertools.product(*range_list))
        width, height = 1,1
        # append new row entry for every pixel locations within y_range and x_range
        for new_x, new_y in combination_list:       
            li.append([row["filename"],  new_x, new_y, width, height, row["class"]])
      
    pixels_df = pd.DataFrame(li, columns=['filename', 'x', 'y', 'width', 'height', 'class'])
    # print(pixels_df.head())
    
    # function to assign pixel RGB values using image dictionary
    def assign_pixels(row):
        return image_dict[row["filename"]][row.y:row.y+1, row.x:row.x+1].flatten()
    pixels_df["RGB"] = pixels_df.apply(lambda row: assign_pixels(row),axis=1)

    # create color channels
    pixels_df["R"] = pixels_df.apply(lambda row: np.int64(row["RGB"][0]),axis=1)
    pixels_df["G"] = pixels_df.apply(lambda row: np.int64(row["RGB"][1]),axis=1)
    pixels_df["B"] = pixels_df.apply(lambda row: np.int64(row["RGB"][2]),axis=1)
    # create temperature column
    pixels_df["temperature"] = pixels_df.apply(lambda row: temp_dict[row["filename"]][:2])
    # change date to pandas datetime
    pixels_df["date"] = pd.to_datetime(pixels_df["date"])

    df = pixels_df[["x","y","R","G","B","temperature", "class"]]

    # drop all missing values
    df = df.fillna(value=np.nan)
    df = df.dropna()
    # remove duplicate RGB
    df = df.drop_duplicates()
    return df

# %%
def wrangle_data(df, folder):
# """
# wrangle via annotated data to produce dataframe of pixel coordinates with their corresponding
# RGB values, class and temperature info
# """
# testing 
# input data: folder of images in example data/ 
#df = csv_1
# here change the name of the files if relevant: 
    df = df.rename(columns = {"filename":"filename_inverted"})
    df["filename"] = df["filename_inverted"].str.replace("invert_", "")

    # extract region attributes to produce class variable

    #here add in create column functionality 

    for i in range(df.shape[0]):
        try:
            json_item = json.loads(df['region_attributes'][i])
            keys = list(json_item["attribute"].keys())
            df.loc[i,"class"] = keys[0]
        except:
            print("Not able to extract region attributes at row {}".format(i))
        
    # convert json code to python dictionary
    for i in range(df.shape[0]):
        dictionary = ast.literal_eval(df.loc[i, "region_shape_attributes"])
        for k,v in dictionary.items():
            df.loc[i,k ] = v
            
    # change to int type
    for col in ["x", "y", "width","height"]:
        df[col] = df[col].astype('Int64')

        
    # dictionary of filename data
    filename_data = {
        'system': [],
        'watershed': [],
        'date': [],
        'time':[],
        'pic_id': [],
    }

    # loop through filename string to add filename data
    for i in range(len(df['filename'])): #used to be file name now invert 
        # split contents by underscore
        file_items = df['filename_inverted'][i].split('_')

        # add system column for 'hbwtr'
        filename_data['system'].append(file_items[1])
        # add watershed olumn, 'w1', 'w2', etc.
        filename_data['watershed'].append(file_items[2])
        # add date column
        filename_data['date'].append(
                                    # modify integer date to date format, MM/DD/YYYY
                                    dt.strptime(file_items[3], '%Y%m%d').strftime('%m/%d/%Y')
                                    )
        filename_data['time'].append(
                                    #modify interger to time format
                                    dt.strptime(file_items[4][:-4],'%H%M%S').strftime('%H:%M:%S')
                                    )
        # add picture id number
        filename_data['pic_id'].append(file_items[4])


    # create columns of this data in dataframe
    for variable in filename_data.keys():
        df[variable] = filename_data[variable]
        

    # make list to reorder columns
    new_cols = ['filename_inverted', 'filename', 'region_count', 'region_id', 'class', 'name', 'x','y', 'width', 'height',  'system','watershed', 'date','time','pic_id']

    df = df[new_cols]

    #create image dictionary and temperature dictionary
    image_dict = {}
    temp_dict = {}

    def my_func(row):
        if row["filename"] in image_dict:
            return
        path =  folder +row["filename"] # sample path to example data folder with all images
        # note to Audrey: can you change this to read the images recursively (e.g. find file regardless of path)
        img= np.asarray(Image.open(path)) #note to Audrey: read in raw images, not inverted images?
        image_dict[row["filename"]] = img
        temp_dict[row["filename"]] = extract_temperature(path)
    _= df.apply(lambda c: my_func(c), axis =1)

    print(temp_dict)   
    #print(temp_dict.get("Hbwtr_w1_20190102_115959.JPG"))
    #print(temp_dict["Hbwtr_w1_20190102_115959.JPG"]) #this also gives the tmperature 
        # # Assign image pixel values for each row by extracting RGB using x,y coordinates
        
    # # drop na values in x and y column
    df = df.dropna(subset= ["x","y"])
    # save new data points to this list
    li = []
    # loop over all rows and poopulate pixel coordinates
    for ind, row in df.iterrows():
        y_range = (row.y, row.y+row.height)
        x_range = (row.x, row.x+row.width)
        # print(y_range, x_range)
        # calculate the coordinates range in the x and y axis
        range_list =  [range(row.x, row.x+row.width), range(row.y,row.y+row.height)]
        # set product of x_range and y_range
        combination_list = list(itertools.product(*range_list))
        width, height = 1,1
        # append new row entry for every pixel locations within y_range and x_range
        for new_x, new_y in combination_list:       
            li.append([row["filename"],  new_x, new_y, width, height, row["class"]])
        
    pixels_df = pd.DataFrame(li, columns=['filename', 'x', 'y', 'width', 'height', 'class'])
    #print(pixels_df.head())
        
    # function to assign pixel RGB values using image dictionary
    def assign_pixels(row):
        return image_dict[row["filename"]][row.y:row.y+1, row.x:row.x+1].flatten()
    pixels_df["RGB"] = pixels_df.apply(lambda row: assign_pixels(row),axis=1)

    # create color channels
    pixels_df["R"] = pixels_df.apply(lambda row: np.int64(row["RGB"][0]),axis=1)
    pixels_df["G"] = pixels_df.apply(lambda row: np.int64(row["RGB"][1]),axis=1)
    pixels_df["B"] = pixels_df.apply(lambda row: np.int64(row["RGB"][2]),axis=1)
    # # create temperature column
    # pixels_df["temperature"] = pixels_df.apply(lambda row: temp_dict[row["filename"]][:2])
    #print(row["filename"])
    pixels_df["temperature"] = pixels_df.apply(lambda row: temp_dict[row["filename"]], axis = 1) #added axis = 1

    file_items_df = df[["filename", "watershed", "date", "time"]].drop_duplicates()

    pixels_df = pixels_df.merge(file_items_df, on="filename")

    df = pixels_df[["x","y","R","G","B","date", "time", "filename", "watershed", "temperature","class"]]

    # drop all missing values
    df = df.fillna(value=np.nan)
    df = df.dropna() #this removes missing values, maybe change this to just drop na on anything that is not temperature 
    # remove duplicate RGB
    df = df.drop_duplicates()

    return df

# %%
# read via annotated image pixels data
# we will use three data sets( from watershed 3 and watershed 6)
#csv_1 = pd.read_csv('data/training_data/input_data/hbwater_w3_bottom_1 1 20-3 5 20_csv.csv') #this file name was swapped out for wrangle
#csv_1 = pd.read_csv('data/training_data/input_data/hbwtr_w1_2019_bottom_TEST.csv')
csv_1 = pd.read_csv('data/training_data/input_data/hbwtr_w1_2019_bottom.csv')
csv_2 = pd.read_csv("data/training_data/input_data/hb2_w6_2019_top_csv.csv")
csv_3 = pd.read_csv("data/training_data/input_data/hbwtr_w6_oct2018dec2018_bottom_csv.csv")
csv_4 = pd.read_csv("data/training_data/input_data/via_project_w1_csv.csv")

csv_4.head()
# Out:
#                               filename  file_size   file_attributes  \
# 0  invert_Hbwtr_w1_20201001_120348.jpg     461442  {"attribute":{}}
# 1  invert_Hbwtr_w1_20201001_120348.jpg     461442  {"attribute":{}}
# 2  invert_Hbwtr_w1_20201001_120348.jpg     461442  {"attribute":{}}
# 3  invert_Hbwtr_w1_20201001_120348.jpg     461442  {"attribute":{}}
# 4  invert_Hbwtr_w1_20201001_120348.jpg     461442  {"attribute":{}}
#
#    region_count  region_id                            region_shape_attributes  \
# 0            22          0  {"name":"rect","x":2934,"y":2677,"width":86,"h...
# 1            22          1  {"name":"rect","x":3114,"y":2612,"width":83,"h...
# 2            22          2  {"name":"rect","x":3238,"y":2612,"width":65,"h...
# 3            22          3  {"name":"rect","x":2712,"y":2928,"width":92,"h...
# 4            22          4  {"name":"rect","x":2148,"y":2984,"width":33,"h...
#
#                    region_attributes
# 0   {"attribute":{"leaf_fall":true}}
# 1   {"attribute":{"leaf_fall":true}}
# 2   {"attribute":{"leaf_fall":true}}
# 3   {"attribute":{"leaf_fall":true}}
# 4  {"attribute":{"leaf_green":true}}

# %%
# a note before running
csv_look = csv_4.copy()
print("the following non-inverted images: ", csv_look["filename"].iloc[1], " & ", csv_4["filename"].iloc[-1], " must be in a folder, usually example_data/")
# Out:
# the following dates:  invert_Hbwtr_w1_20201001_120348.jpg  &  invert_Hbwtr_w1_20211031_115957.JPG  must be in example data

# %%
# main function
# csv_1 = wrangle_data(df = csv_1, folder = "example_data/") #takes 10 mins 
# csv_2 = wrangle_data(csv_2)
# csv_3 = wrangle_data(csv_3)
csv_4 = wrangle_data(csv_4, "data/munged/W1/")

# wrangle and save dataset
# csv_1.to_csv("data/training_data/derived/pixels_df_1.csv", index=False)
# csv_2.to_csv("data/training_data/derived/pixels_df_2.csv", index=False)
# csv_3.to_csv("data/training_data/derived/pixels_df_3.csv", index=False)
csv_4.to_csv("data/training_data/derived/pixels_df_4.csv", index = False)
# Out:
# Not able to extract region attributes at row 59
# Not able to extract region attributes at row 138
# Not able to extract region attributes at row 197
# Not able to extract region attributes at row 251
# Not able to extract region attributes at row 328
# Not able to extract region attributes at row 426
# Not able to extract region attributes at row 479
# Not able to extract region attributes at row 502
# Not able to extract region attributes at row 563
# Not able to extract region attributes at row 643
# Not able to extract region attributes at row 644
# Not able to extract region attributes at row 645
# Not able to extract region attributes at row 646
# Not able to extract region attributes at row 647
# Not able to extract region attributes at row 648
# Not able to extract region attributes at row 649
# Not able to extract region attributes at row 650
# Not able to extract region attributes at row 651
# Not able to extract region attributes at row 652
# Not able to extract region attributes at row 653
# Not able to extract region attributes at row 654
# Not able to extract region attributes at row 655
# Not able to extract region attributes at row 656
# Not able to extract region attributes at row 657
# Not able to extract region attributes at row 658
# Not able to extract region attributes at row 659
# Not able to extract region attributes at row 660
# Not able to extract region attributes at row 661
# Not able to extract region attributes at row 662
# Not able to extract region attributes at row 663
# Not able to extract region attributes at row 664
# Not able to extract region attributes at row 665
# Not able to extract region attributes at row 666
# Not able to extract region attributes at row 667
# Not able to extract region attributes at row 668
# Not able to extract region attributes at row 669
# Not able to extract region attributes at row 670
# Not able to extract region attributes at row 671
# Not able to extract region attributes at row 672
# Not able to extract region attributes at row 673
# Not able to extract region attributes at row 674
# Not able to extract region attributes at row 675
# Not able to extract region attributes at row 676
# Not able to extract region attributes at row 677
# Not able to extract region attributes at row 678
# Not able to extract region attributes at row 679
# Not able to extract region attributes at row 680
# Not able to extract region attributes at row 681
# Not able to extract region attributes at row 682
# Not able to extract region attributes at row 683
# Not able to extract region attributes at row 684
# Not able to extract region attributes at row 685
# Not able to extract region attributes at row 686
# Not able to extract region attributes at row 687
# Not able to extract region attributes at row 688
# Not able to extract region attributes at row 689
# Not able to extract region attributes at row 690
# Not able to extract region attributes at row 691
# Not able to extract region attributes at row 692
# Not able to extract region attributes at row 693
# Not able to extract region attributes at row 694
# Not able to extract region attributes at row 695
# Not able to extract region attributes at row 696
# Not able to extract region attributes at row 697
# Not able to extract region attributes at row 698
# Not able to extract region attributes at row 699
# Not able to extract region attributes at row 700
# Not able to extract region attributes at row 701
# Not able to extract region attributes at row 702
# Not able to extract region attributes at row 703
# Not able to extract region attributes at row 704
# Not able to extract region attributes at row 705
# Not able to extract region attributes at row 706
# Not able to extract region attributes at row 707
# Not able to extract region attributes at row 708
# Not able to extract region attributes at row 709
# Not able to extract region attributes at row 710
# Not able to extract region attributes at row 711
# Not able to extract region attributes at row 712
# Not able to extract region attributes at row 713
# Not able to extract region attributes at row 714
# Not able to extract region attributes at row 715
# Not able to extract region attributes at row 716
# Not able to extract region attributes at row 717
# Not able to extract region attributes at row 718
# Not able to extract region attributes at row 719
# Not able to extract region attributes at row 720
# Not able to extract region attributes at row 721
# Not able to extract region attributes at row 722
# Not able to extract region attributes at row 723
# Not able to extract region attributes at row 724
# Not able to extract region attributes at row 725
# Not able to extract region attributes at row 726
# Not able to extract region attributes at row 727
# Not able to extract region attributes at row 728
# Not able to extract region attributes at row 729
# Not able to extract region attributes at row 730
# Not able to extract region attributes at row 731
# Not able to extract region attributes at row 732
# Not able to extract region attributes at row 733
# Not able to extract region attributes at row 734
# Not able to extract region attributes at row 735
# Not able to extract region attributes at row 736
# Not able to extract region attributes at row 737
# Not able to extract region attributes at row 738
# Not able to extract region attributes at row 739
# Not able to extract region attributes at row 740
# Not able to extract region attributes at row 741
# Not able to extract region attributes at row 742
# Not able to extract region attributes at row 743
# Not able to extract region attributes at row 744
# Not able to extract region attributes at row 745
# Not able to extract region attributes at row 746
# Not able to extract region attributes at row 747
# Not able to extract region attributes at row 748
# Not able to extract region attributes at row 749
# Not able to extract region attributes at row 750
# Not able to extract region attributes at row 751
# Not able to extract region attributes at row 752
# Not able to extract region attributes at row 753
# Not able to extract region attributes at row 754
# Not able to extract region attributes at row 755
# Not able to extract region attributes at row 756
# Not able to extract region attributes at row 757
# Not able to extract region attributes at row 758
# Not able to extract region attributes at row 759
# Not able to extract region attributes at row 760
# Not able to extract region attributes at row 761
# Not able to extract region attributes at row 762
# Not able to extract region attributes at row 763
# Not able to extract region attributes at row 764
# Not able to extract region attributes at row 765
# Not able to extract region attributes at row 766
# Not able to extract region attributes at row 767
# Not able to extract region attributes at row 768
# Not able to extract region attributes at row 769
# Not able to extract region attributes at row 770
# Not able to extract region attributes at row 771
# Not able to extract region attributes at row 772
# Not able to extract region attributes at row 773
# Not able to extract region attributes at row 774
# Not able to extract region attributes at row 775
# Not able to extract region attributes at row 776
# Not able to extract region attributes at row 777
# Not able to extract region attributes at row 778
# Not able to extract region attributes at row 779
# Not able to extract region attributes at row 780
# Not able to extract region attributes at row 781
# Not able to extract region attributes at row 782
# Not able to extract region attributes at row 783
# Not able to extract region attributes at row 784
# Not able to extract region attributes at row 785
# Not able to extract region attributes at row 786
# Not able to extract region attributes at row 787
# Not able to extract region attributes at row 788
# Not able to extract region attributes at row 789
# Not able to extract region attributes at row 790
# Not able to extract region attributes at row 791
# Not able to extract region attributes at row 792
# Not able to extract region attributes at row 793
# Not able to extract region attributes at row 848
# Not able to extract region attributes at row 897
# Not able to extract region attributes at row 903
# Not able to extract region attributes at row 954
# Not able to extract region attributes at row 1000
# Not able to extract region attributes at row 1032
# Not able to extract region attributes at row 1042
# Not able to extract region attributes at row 1046
# Not able to extract region attributes at row 1061
# Not able to extract region attributes at row 1084
# Not able to extract region attributes at row 1114
# Not able to extract region attributes at row 1202
# Not able to extract region attributes at row 1238
# Not able to extract region attributes at row 1249
# Not able to extract region attributes at row 1317
# Not able to extract region attributes at row 1419
# Not able to extract region attributes at row 1420
# Not able to extract region attributes at row 1429
# Not able to extract region attributes at row 1443
# Not able to extract region attributes at row 1444
# Not able to extract region attributes at row 1445
# Not able to extract region attributes at row 1497
# Not able to extract region attributes at row 1498
# Not able to extract region attributes at row 1499
# Not able to extract region attributes at row 1500
# Not able to extract region attributes at row 1501
# Not able to extract region attributes at row 1518
# Not able to extract region attributes at row 1610
# Not able to extract region attributes at row 1617
# Not able to extract region attributes at row 1618
# Not able to extract region attributes at row 1619
# Not able to extract region attributes at row 1620
# Not able to extract region attributes at row 1621
# Not able to extract region attributes at row 1622
# Not able to extract region attributes at row 1623
# Not able to extract region attributes at row 1624
# Not able to extract region attributes at row 1625
# Not able to extract region attributes at row 1626
# Not able to extract region attributes at row 1627
# Not able to extract region attributes at row 1628
# Not able to extract region attributes at row 1629
# Not able to extract region attributes at row 1630
# Not able to extract region attributes at row 1631
# Not able to extract region attributes at row 1632
# Not able to extract region attributes at row 1633
# Not able to extract region attributes at row 1634
# Not able to extract region attributes at row 1635
# Not able to extract region attributes at row 1639
# Not able to extract region attributes at row 1642
# Not able to extract region attributes at row 1649
# Not able to extract region attributes at row 1660
# Not able to extract region attributes at row 1661
# Not able to extract region attributes at row 1662
# Not able to extract region attributes at row 1663
# Not able to extract region attributes at row 1674
# Not able to extract region attributes at row 1675
# Not able to extract region attributes at row 1676
# Not able to extract region attributes at row 1677
# Not able to extract region attributes at row 1678
# Not able to extract region attributes at row 1679
# Not able to extract region attributes at row 1680
# Not able to extract region attributes at row 1681
# Not able to extract region attributes at row 1682
# Not able to extract region attributes at row 1683
# Not able to extract region attributes at row 1684
# Not able to extract region attributes at row 1685
# Not able to extract region attributes at row 1686
# Not able to extract region attributes at row 1687
# Not able to extract region attributes at row 1688
# Not able to extract region attributes at row 1689
# Not able to extract region attributes at row 1703
# Not able to extract region attributes at row 1704
# Not able to extract region attributes at row 1705
# Not able to extract region attributes at row 1706
# Not able to extract region attributes at row 1707
# Not able to extract region attributes at row 1708
# Not able to extract region attributes at row 1709
# Not able to extract region attributes at row 1710
# Not able to extract region attributes at row 1711
# Not able to extract region attributes at row 1712
# Not able to extract region attributes at row 1713
# Not able to extract region attributes at row 1714
# Not able to extract region attributes at row 1715
# Not able to extract region attributes at row 1716
# Not able to extract region attributes at row 1717
# Not able to extract region attributes at row 1718
# Not able to extract region attributes at row 1719
# Not able to extract region attributes at row 1720
# Not able to extract region attributes at row 1721
# Not able to extract region attributes at row 1722
# Not able to extract region attributes at row 1723
# Not able to extract region attributes at row 1724
# Not able to extract region attributes at row 1725
# Not able to extract region attributes at row 1726
# Not able to extract region attributes at row 1727
# Not able to extract region attributes at row 1728
# Not able to extract region attributes at row 1729
# Not able to extract region attributes at row 1730
# Not able to extract region attributes at row 1731
# Not able to extract region attributes at row 1732
# Not able to extract region attributes at row 1733
# Not able to extract region attributes at row 1734
# Not able to extract region attributes at row 1735
# Not able to extract region attributes at row 1736
# Not able to extract region attributes at row 1737
# Not able to extract region attributes at row 1741
# Not able to extract region attributes at row 1757
# Not able to extract region attributes at row 1758
# Not able to extract region attributes at row 1759
# Not able to extract region attributes at row 1760
# Not able to extract region attributes at row 1761
# Not able to extract region attributes at row 1762
# Not able to extract region attributes at row 1763
# Not able to extract region attributes at row 1764
# Not able to extract region attributes at row 1765
# Not able to extract region attributes at row 1766
# Not able to extract region attributes at row 1767
# Not able to extract region attributes at row 1768
# Not able to extract region attributes at row 1769
# Not able to extract region attributes at row 1770
# Not able to extract region attributes at row 1771
# Not able to extract region attributes at row 1772
# Not able to extract region attributes at row 1773
# Not able to extract region attributes at row 1774
# Not able to extract region attributes at row 1775
# Not able to extract region attributes at row 1776
# Not able to extract region attributes at row 1777
# Not able to extract region attributes at row 1778
# Not able to extract region attributes at row 1779
# Not able to extract region attributes at row 1780
# Not able to extract region attributes at row 1781
# Not able to extract region attributes at row 1782
# Not able to extract region attributes at row 1783
# Not able to extract region attributes at row 1784
# Not able to extract region attributes at row 1785
# Not able to extract region attributes at row 1786
# Not able to extract region attributes at row 1787
# Not able to extract region attributes at row 1788
# Not able to extract region attributes at row 1789
# Not able to extract region attributes at row 1790
# Not able to extract region attributes at row 1791
# Not able to extract region attributes at row 1792
# Not able to extract region attributes at row 1793
# Not able to extract region attributes at row 1794
# Not able to extract region attributes at row 1795
# Not able to extract region attributes at row 1796
# Not able to extract region attributes at row 1797
# Not able to extract region attributes at row 1798
# Not able to extract region attributes at row 1799
# Not able to extract region attributes at row 1800
# Not able to extract region attributes at row 1801
# Not able to extract region attributes at row 1802
# Not able to extract region attributes at row 1803
# Not able to extract region attributes at row 1804
# Not able to extract region attributes at row 1805
# Not able to extract region attributes at row 1806
# Not able to extract region attributes at row 1807
# Not able to extract region attributes at row 1808
# Not able to extract region attributes at row 1809
# Not able to extract region attributes at row 1810
# Not able to extract region attributes at row 1811
# Not able to extract region attributes at row 1812
# Not able to extract region attributes at row 1813
# Not able to extract region attributes at row 1814
# Not able to extract region attributes at row 1815
# Not able to extract region attributes at row 1816
# Not able to extract region attributes at row 1817
# Not able to extract region attributes at row 1818
# Not able to extract region attributes at row 1819
# Not able to extract region attributes at row 1820
# Not able to extract region attributes at row 1821
